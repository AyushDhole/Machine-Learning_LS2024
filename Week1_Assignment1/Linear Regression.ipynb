# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel('C:/Users/Lenovo/Downloads/Training data.xlsx')

# %%
x_train = np.array(df.iloc[:,0:8])
y_train = np.array(df.iloc[:,8]).reshape(-1,1)
df.head()
# Out:
#    traveltime  studytime  freetime  absences  age   iq  internet_yes  sex_M  \
# 0           2          2         5         6   18  118             0      1
# 1           2          2         2         7   19  107             1      1
# 2           3          3         3         5   18  108             1      1
# 3           3          3         4         9   17  100             0      0
# 4           1          4         3         4   19   96             1      1
#
#      Mks
# 0  73.13
# 1  67.78
# 2  70.84
# 3  66.68
# 4  71.88

# %%
sns.jointplot(x= df["iq"], y=df['marks'], data= df)
# Out:
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\Lenovo\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
df = pd.get_dummies(df, dtype='int')
df.head()
# Out:
#    traveltime  studytime  freetime  absences  age   iq  marks  internet_yes  \
# 0           2          2         5         6   18  118  73.13             0
# 1           2          2         2         7   19  107  67.78             1
# 2           3          3         3         5   18  108  70.84             1
# 3           3          3         4         9   17  100  66.68             0
# 4           1          4         3         4   19   96  71.88             1
#
#    sex_F  sex_M
# 0      0      1
# 1      0      1
# 2      0      1
# 3      1      0
# 4      0      1

# %%
df.head()
# Out:
#    traveltime  studytime  freetime  absences  age   iq  marks  internet_yes  \
# 0           2          2         5         6   18  118  73.13             0
# 1           2          2         2         7   19  107  67.78             1
# 2           3          3         3         5   18  108  70.84             1
# 3           3          3         4         9   17  100  66.68             0
# 4           1          4         3         4   19   96  71.88             1
#
#    sex_M
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1

# %%
sns.pairplot()

# %%
df['Mks'] = df['marks']
del df['marks']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marks'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[97], line 1
# ----> 1 df['Mks'] = df['marks']
#       2 del df['marks']
#       3 df.head()
#
# ...

# %%
df.head()
# Out:
#    traveltime  studytime  freetime  absences  age   iq  internet_yes  sex_M  \
# 0           2          2         5         6   18  118             0      1
# 1           2          2         2         7   19  107             1      1
# 2           3          3         3         5   18  108             1      1
# 3           3          3         4         9   17  100             0      0
# 4           1          4         3         4   19   96             1      1
#
#      Mks
# 0  73.13
# 1  67.78
# 2  70.84
# 3  66.68
# 4  71.88
